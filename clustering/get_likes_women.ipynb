# %%
import numpy as np
import pandas as pd

# %%
# file = "./Dating Preferences! (Women Profiles) (Responses) - Form Responses 1.csv"
file = "./Dating Preferences! (Profiles of Men) (Responses) - Form Responses 1.csv"

# %%
# load the csv file
df = pd.read_csv(file)

# get all rows
rows = df.shape[0]

df.drop(df.columns[0], axis=1, inplace=True)
df.drop(df.columns[0], axis=1, inplace=True)

# get all rows in a list
data = df.values.tolist()

df
# Out:
#    Swipe Right? Swipe Right?.1 Swipe Right?.2 Swipe Right?.3 Swipe Right?.4  \
# 0       Like :)     Dislike :(        Like :)     Dislike :(        Like :)
# 1    Dislike :(     Dislike :(     Dislike :(        Like :)        Like :)
# 2    Dislike :(        Like :)        Like :)        Like :)     Dislike :(
# 3    Dislike :(        Like :)        Like :)        Like :)     Dislike :(
# 4    Dislike :(        Like :)     Dislike :(     Dislike :(        Like :)
# 5    Dislike :(        Like :)     Dislike :(        Like :)     Dislike :(
# 6    Dislike :(        Like :)     Dislike :(     Dislike :(     Dislike :(
# 7    Dislike :(     Dislike :(        Like :)        Like :)        Like :)
# 8    Dislike :(        Like :)        Like :)     Dislike :(     Dislike :(
# 9    Dislike :(     Dislike :(     Dislike :(     Dislike :(     Dislike :(
# 10   Dislike :(        Like :)        Like :)     Dislike :(        Like :)
# ...

# %%
lis = []
for i in range(len(data)):
    l = data[i]
    tmp = []
    for e in l:
        if e == "Like :)":
            tmp.append(1)
        elif e == "Dislike :(":
            tmp.append(0)
    lis.append(tmp)

# %%
np.array(lis).shape

# save the data
# np.save("men_profile_preferences.npy", np.array(lis))

# %%
np.array(lis).shape
# Out:
# (15, 30)
