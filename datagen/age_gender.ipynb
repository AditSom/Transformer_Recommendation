# %% [markdown]
# <a href="https://colab.research.google.com/github/AditSom/Transformer_Recommendation/blob/main/age_gender.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from deepface import DeepFace

# %%
obj = DeepFace.analyze(img_path = "man_2.jpeg", actions = ["age", "gender"])
# Out:
# Action: gender: 100%|██████████| 2/2 [00:01<00:00,  1.50it/s]

# %%
for f in file: # TODO: add file directory to run through images
  obj = DeepFace.analyze(img_path = f, actions = ["age", "gender"])
  age = obj[0]["age"]
  woman, man = obj[0]["gender"].values()
  if man > woman:
    gender = "man"
  else:
    gender = "woman"

  if age > 20 and age < 30:
    if gender == "man":
      #TODO: append file in folder for men
      pass
    else:
      #TODO: append file in folder for women
      pass
# Out:
# 33
# Man
